# %%
# !sudo apt-get update -qq
# !sudo apt-get install -y -qq git
# !git clone -b full_tf_simple https://github.com/LonelyLemon/NLP-Project.git
# %cd NLP-Project
# !ls
# Out:
# fatal: destination path 'NLP-Project' already exists and is not an empty directory.
# /home/admin/NLP-Project
# best_model.pt			   spm_en.vocab
# data				   spm_vi.model
# main.py				   spm_vi.vocab
# notebooks			   src
# posttraining_schedule_sampling.py  train_transformer.py
# __pycache__			   uv.lock
# pyproject.toml			   vlsp
# README.md			   VLSP_Qwen_LoRA_Medical_Summarization.ipynb
# spm_en.model
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -q --upgrade pip
# !pip install -q --upgrade pyparsing torch torchvision torchaudio \
            datasets sentencepiece sacrebleu rouge-score tqdm \
            numpy matplotlib seaborn

# %%
import sys
sys.path.insert(0, "/home/admin/.local/lib/python3.10/site-packages")

# %%
from train_transformer import main
config = {
    'src': 'en',
    'trg': 'vi',
    'use_swig': False,
    'use_rope': True,
    'vocab_size_en': 18000,
    'vocab_size_vi': 10500,
    'vocab_model_type': 'unigram',
    'num_workers': 20,

    'model_dim': 384,
    'ff_hidden_dim': 1536,
    'num_heads': 6,
    'num_enc_layers': 4,
    'num_dec_layers': 4,
    'dropout': 0.2,
    'max_len_en': 150,
    'max_len_vi': 180,

    'batch_size': 64,
    'num_epochs': 50,
    'warmup_steps': 4000,
    'train_en_path': 'data/task1/train.en.txt',
    'train_vi_path': 'data/task1/train.vi.txt',
    'valid_en_path': 'data/task1/valid.en.txt',
    'valid_vi_path': 'data/task1/valid.vi.txt',
    'test_en_path': 'data/task1/test.en.txt',
    'test_vi_path': 'data/task1/test.vi.txt',
}

main(config)
# Out:
# Device: cuda
# CONFIGURATION
# src : en
# trg : vi
# use_rope : True
# use_swig : False
# vocab_size_en : 18000
# vocab_size_vi : 10500
# vocab_model_type : unigram
# num_workers : 20
# model_dim : 384
# num_heads : 6
# num_enc_layers : 4
# num_dec_layers : 4
# ff_hidden_dim : 1536
# dropout : 0.2
# max_len_en : 150
# max_len_vi : 180
# batch_size : 64
# num_epochs : 50
# learning_rate : 5e-05
# weight_decay : 1e-05
# warmup_steps : 4000
# patience : 5
# freq_threshold : 2
# beam_size : 5
# length_penalty : 0.6
# train_en_path : data/task1/train.en.txt
# train_vi_path : data/task1/train.vi.txt
# valid_en_path : data/task1/valid.en.txt
# valid_vi_path : data/task1/valid.vi.txt
# test_en_path : data/task1/test.en.txt
# test_vi_path : data/task1/test.vi.txt
# Map:   0%|          | 0/133317 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1553 [00:00<?, ? examples/s]
#   Train samples: 133,317
#   Val samples:   1,268
#   Test samples:  1,553
# ============================================================
#
# Building vocabulary...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.en
#   input_format:
#   model_prefix: spm_en
#   model_type: UNIGRAM
#   vocab_size: 18000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.en
# trainer_interface.cc(411) LOG(INFO) Loaded all 133168 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13164888
# trainer_interface.cc(562) LOG(INFO) Alphabet size=97
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133168 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6701618
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 83413 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133168
# trainer_interface.cc(611) LOG(INFO) Done! 47854
# unigram_model_trainer.cc(602) LOG(INFO) Using 47854 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=33457 obj=9.47102 num_tokens=99225 num_tokens/piece=2.96575
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=25855 obj=7.58489 num_tokens=100273 num_tokens/piece=3.87828
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=19797 obj=7.51373 num_tokens=104658 num_tokens/piece=5.28656
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=19781 obj=7.49587 num_tokens=104760 num_tokens/piece=5.29599
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_en.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_en.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.vi
#   input_format:
#   model_prefix: spm_vi
#   model_type: UNIGRAM
#   vocab_size: 10500
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.vi
# trainer_interface.cc(411) LOG(INFO) Loaded all 133205 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13571933
# trainer_interface.cc(552) LOG(INFO) Done: 99.9548% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=110
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999548
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133205 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6355933
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 29935 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133205
# trainer_interface.cc(611) LOG(INFO) Done! 22399
# unigram_model_trainer.cc(602) LOG(INFO) Using 22399 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=17291 obj=8.22202 num_tokens=46800 num_tokens/piece=2.70661
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=14212 obj=6.87387 num_tokens=46046 num_tokens/piece=3.23994
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=11542 obj=6.79845 num_tokens=46569 num_tokens/piece=4.03474
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=11500 obj=6.78966 num_tokens=46559 num_tokens/piece=4.04861
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_vi.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_vi.vocab
# Creating dataloaders...
# Creating Transformer model...
# Total parameters: 31550724
# Trainable parameters: 31550724
# Setting up training...
# Epoch 1 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.92it/s, loss=4.2526, lr=4.20e-04]
# Epoch 1 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.78it/s, loss=4.7785]
# Epoch 1 | Train: 5.2866 | Val: 4.2669 | LR: 0.000420
# Checkpoint saved: best_model.pt
# Epoch 2 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.73it/s, loss=4.2915, lr=7.90e-04]
# Epoch 2 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.48it/s, loss=4.1708]
# Epoch 2 | Train: 4.0492 | Val: 3.6817 | LR: 0.000790
# Checkpoint saved: best_model.pt
# Epoch 3 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.76it/s, loss=3.2226, lr=6.45e-04]
# Epoch 3 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.05it/s, loss=3.7849]
# Epoch 3 | Train: 3.6264 | Val: 3.2871 | LR: 0.000645
# Checkpoint saved: best_model.pt
# Epoch 4 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.47it/s, loss=2.9773, lr=5.59e-04]
# Epoch 4 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.10it/s, loss=3.5674]
# Epoch 4 | Train: 3.3491 | Val: 3.1052 | LR: 0.000559
# Checkpoint saved: best_model.pt
# Epoch 5 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.58it/s, loss=3.2060, lr=5.00e-04]
# Epoch 5 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 34.24it/s, loss=3.4528]
# Epoch 5 | Train: 3.1742 | Val: 2.9654 | LR: 0.000500
# Checkpoint saved: best_model.pt
# Epoch 6 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.75it/s, loss=3.3389, lr=4.56e-04]
# Epoch 6 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.76it/s, loss=3.3495]
# Epoch 6 | Train: 3.0551 | Val: 2.8943 | LR: 0.000456
# Checkpoint saved: best_model.pt
# Epoch 7 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.64it/s, loss=3.0387, lr=4.23e-04]
# Epoch 7 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.04it/s, loss=3.2923]
# Epoch 7 | Train: 2.9665 | Val: 2.8340 | LR: 0.000423
# Checkpoint saved: best_model.pt
# Epoch 9 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.74it/s, loss=2.8784, lr=3.73e-04]
# Epoch 9 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.58it/s, loss=3.2175]
# Epoch 9 | Train: 2.8414 | Val: 2.7552 | LR: 0.000373
# Checkpoint saved: best_model.pt
# Epoch 10 [Train]:  15%|█▌        | 316/2084 [00:11<01:00, 29.15it/s, loss=2.8637, lr=3.69e-04]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Epoch 18 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.88it/s, loss=2.0786, lr=2.63e-04]
# Epoch 18 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.98it/s, loss=2.9923]
# Epoch 18 | Train: 2.5751 | Val: 2.6060 | LR: 0.000263
# Checkpoint saved: best_model.pt
# Epoch 19 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.51it/s, loss=2.4995, lr=2.56e-04]
# Epoch 19 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.82it/s, loss=2.9840]
# Epoch 19 | Train: 2.5598 | Val: 2.6032 | LR: 0.000256
# Checkpoint saved: best_model.pt
# Epoch 20 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.70it/s, loss=2.7667, lr=2.50e-04]
# Epoch 20 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.63it/s, loss=2.9781]
# Epoch 20 | Train: 2.5430 | Val: 2.5934 | LR: 0.000250
# Checkpoint saved: best_model.pt
# Epoch 21 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.63it/s, loss=2.6098, lr=2.44e-04]
# Epoch 21 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.56it/s, loss=2.9527]
# Epoch 21 | Train: 2.5277 | Val: 2.5829 | LR: 0.000244
# Checkpoint saved: best_model.pt
# Epoch 22 [Train]:  58%|█████▊    | 1219/2084 [00:44<00:33, 26.00it/s, loss=2.6323, lr=2.41e-04]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Epoch 23 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.55it/s, loss=2.1236, lr=2.33e-04]
# Epoch 23 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.09it/s, loss=2.9460]
# Epoch 23 | Train: 2.4996 | Val: 2.5719 | LR: 0.000233
# Checkpoint saved: best_model.pt
# Epoch 24 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.66it/s, loss=2.8304, lr=2.28e-04]
# Epoch 24 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.51it/s, loss=2.9453]
# Epoch 24 | Train: 2.4880 | Val: 2.5685 | LR: 0.000228
# Checkpoint saved: best_model.pt
# Epoch 25 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.68it/s, loss=2.5891, lr=2.24e-04]
# Epoch 25 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.94it/s, loss=2.9405]
# Epoch 25 | Train: 2.4764 | Val: 2.5642 | LR: 0.000224
# Checkpoint saved: best_model.pt
# Epoch 26 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.82it/s, loss=2.7112, lr=2.19e-04]
# Epoch 26 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.83it/s, loss=2.9261]
# Epoch 26 | Train: 2.4661 | Val: 2.5555 | LR: 0.000219
# Checkpoint saved: best_model.pt
# Epoch 27 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.72it/s, loss=2.5730, lr=2.15e-04]
# Epoch 27 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.23it/s, loss=2.9340]
# Epoch 27 | Train: 2.4550 | Val: 2.5589 | LR: 0.000215
# Epoch 28 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.76it/s, loss=1.9943, lr=2.11e-04]
# Epoch 28 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.86it/s, loss=2.9277]
# Epoch 28 | Train: 2.4451 | Val: 2.5482 | LR: 0.000211
# Checkpoint saved: best_model.pt
# Epoch 29 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.72it/s, loss=2.6929, lr=2.08e-04]
# Epoch 29 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.89it/s, loss=2.9225]
# Epoch 29 | Train: 2.4357 | Val: 2.5471 | LR: 0.000208
# Checkpoint saved: best_model.pt
# Epoch 30 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.41it/s, loss=2.7423, lr=2.04e-04]
# Epoch 30 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.76it/s, loss=2.9351]
# Epoch 30 | Train: 2.4269 | Val: 2.5414 | LR: 0.000204
# Checkpoint saved: best_model.pt
# Epoch 31 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.32it/s, loss=1.7849, lr=2.01e-04]
# Epoch 31 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.25it/s, loss=2.9053]
# Epoch 31 | Train: 2.4174 | Val: 2.5386 | LR: 0.000201
# Checkpoint saved: best_model.pt
# Epoch 32 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.37it/s, loss=2.4901, lr=1.98e-04]
# Epoch 32 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.18it/s, loss=2.8990]
# Epoch 32 | Train: 2.4097 | Val: 2.5355 | LR: 0.000198
# Checkpoint saved: best_model.pt
# Epoch 33 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.30it/s, loss=2.4146, lr=1.95e-04]
# Epoch 33 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.34it/s, loss=2.8960]
# Epoch 33 | Train: 2.4014 | Val: 2.5316 | LR: 0.000195
# Checkpoint saved: best_model.pt
# Epoch 34 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.69it/s, loss=2.1732, lr=1.92e-04]
# Epoch 34 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.34it/s, loss=2.8718]
# Epoch 34 | Train: 2.3935 | Val: 2.5328 | LR: 0.000192
# Epoch 35 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.73it/s, loss=2.7014, lr=1.89e-04]
# Epoch 35 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.14it/s, loss=2.8853]
# Epoch 35 | Train: 2.3882 | Val: 2.5308 | LR: 0.000189
# Checkpoint saved: best_model.pt
# Epoch 36 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.70it/s, loss=2.2906, lr=1.86e-04]
# Epoch 36 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.76it/s, loss=2.8702]
# Epoch 36 | Train: 2.3806 | Val: 2.5261 | LR: 0.000186
# Checkpoint saved: best_model.pt
# Epoch 37 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.42it/s, loss=2.7515, lr=1.84e-04]
# Epoch 37 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.94it/s, loss=2.8779]
# Epoch 37 | Train: 2.3745 | Val: 2.5200 | LR: 0.000184
# Checkpoint saved: best_model.pt
# Epoch 38 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.66it/s, loss=1.8914, lr=1.81e-04]
# Epoch 38 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.21it/s, loss=2.8493]
# Epoch 38 | Train: 2.3672 | Val: 2.5139 | LR: 0.000181
# Checkpoint saved: best_model.pt
# Epoch 39 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.73it/s, loss=2.6242, lr=1.79e-04]
# Epoch 39 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.91it/s, loss=2.8712]
# Epoch 39 | Train: 2.3611 | Val: 2.5138 | LR: 0.000179
# Checkpoint saved: best_model.pt
# Epoch 40 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.68it/s, loss=2.0557, lr=1.77e-04]
# Epoch 40 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.17it/s, loss=2.8663]
# Epoch 40 | Train: 2.3553 | Val: 2.5121 | LR: 0.000177
# Checkpoint saved: best_model.pt
# Epoch 41 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.32it/s, loss=2.6392, lr=1.75e-04]
# Epoch 41 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.76it/s, loss=2.8396]
# Epoch 41 | Train: 2.3490 | Val: 2.5102 | LR: 0.000175
# Checkpoint saved: best_model.pt
# Epoch 42 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.38it/s, loss=2.3886, lr=1.72e-04]
# Epoch 42 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 33.16it/s, loss=2.8639]
# Epoch 42 | Train: 2.3440 | Val: 2.5131 | LR: 0.000172
# Epoch 43 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.37it/s, loss=2.4547, lr=1.70e-04]
# Epoch 43 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.08it/s, loss=2.8490]
# Epoch 43 | Train: 2.3385 | Val: 2.5102 | LR: 0.000170
# Checkpoint saved: best_model.pt
# Epoch 45 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.70it/s, loss=2.3789, lr=1.67e-04]
# Epoch 45 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.52it/s, loss=2.8509]
# Epoch 45 | Train: 2.3267 | Val: 2.5024 | LR: 0.000167
# Checkpoint saved: best_model.pt
# Epoch 46 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.33it/s, loss=2.4613, lr=1.65e-04]
# Epoch 46 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.49it/s, loss=2.8634]
# Epoch 46 | Train: 2.3222 | Val: 2.5061 | LR: 0.000165
# Epoch 47 [Train]: 100%|██████████| 2084/2084 [01:16<00:00, 27.25it/s, loss=2.4127, lr=1.63e-04]
# Epoch 47 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.12it/s, loss=2.8542]
# Epoch 47 | Train: 2.3165 | Val: 2.5078 | LR: 0.000163
# Epoch 48 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.61it/s, loss=2.4018, lr=1.61e-04]
# Epoch 48 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.25it/s, loss=2.8385]
# Epoch 48 | Train: 2.3125 | Val: 2.4998 | LR: 0.000161
# Checkpoint saved: best_model.pt
# Epoch 49 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.57it/s, loss=2.3158, lr=1.60e-04]
# Epoch 49 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.15it/s, loss=2.8218]
# Epoch 49 | Train: 2.3078 | Val: 2.4971 | LR: 0.000160
# Checkpoint saved: best_model.pt
# Epoch 50 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.70it/s, loss=2.6782, lr=1.58e-04]
# Epoch 50 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.58it/s, loss=2.8323]
# Epoch 50 | Train: 2.3036 | Val: 2.5012 | LR: 0.000158
# Training history saved at history.json
# Training completed | Best Val Loss: 2.4971
# 100%|██████████| 1553/1553 [02:17<00:00, 11.33it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 26.29
# 100%|██████████| 1553/1553 [11:49<00:00,  2.19it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 27.06
# Comparison of decoding strategies:
# Greedy BLEU: 26.29
# Beam BLEU:   27.06
# Improvement: 0.78
# ✅ Saved: figures/training_curves.png
# Saved BLEU comparison figure at figures/bleu_comparison.png
# Saved loss histogram at figures/loss_histogram.png
# Saved summary table at figures/summary_table.png
