# %%
# !sudo apt-get update -qq
# !sudo apt-get install -y -qq git
# !git clone -b full_tf_simple https://github.com/LonelyLemon/NLP-Project.git
# %cd NLP-Project
# !ls
# Out:
# debconf: delaying package configuration, since apt-utils is not installed
# (Reading database ... 15407 files and directories currently installed.)
# Preparing to unpack .../perl-base_5.34.0-3ubuntu1.5_amd64.deb ...
# Unpacking perl-base (5.34.0-3ubuntu1.5) over (5.34.0-3ubuntu1.3) ...
# Setting up perl-base (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package perl-modules-5.34.
# (Reading database ... 15407 files and directories currently installed.)
# Preparing to unpack .../00-perl-modules-5.34_5.34.0-3ubuntu1.5_all.deb ...
# Unpacking perl-modules-5.34 (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package libgdbm6:amd64.
# Preparing to unpack .../01-libgdbm6_1.23-1_amd64.deb ...
# Unpacking libgdbm6:amd64 (1.23-1) ...
# Selecting previously unselected package libgdbm-compat4:amd64.
# Preparing to unpack .../02-libgdbm-compat4_1.23-1_amd64.deb ...
# Unpacking libgdbm-compat4:amd64 (1.23-1) ...
# Selecting previously unselected package libperl5.34:amd64.
# Preparing to unpack .../03-libperl5.34_5.34.0-3ubuntu1.5_amd64.deb ...
# Unpacking libperl5.34:amd64 (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package perl.
# Preparing to unpack .../04-perl_5.34.0-3ubuntu1.5_amd64.deb ...
# Unpacking perl (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package less.
# Preparing to unpack .../05-less_590-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking less (590-1ubuntu0.22.04.3) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../06-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package liberror-perl.
# Preparing to unpack .../07-liberror-perl_0.17029-1_all.deb ...
# Unpacking liberror-perl (0.17029-1) ...
# Selecting previously unselected package git-man.
# Preparing to unpack .../08-git-man_1%3a2.34.1-1ubuntu1.15_all.deb ...
# Unpacking git-man (1:2.34.1-1ubuntu1.15) ...
# Selecting previously unselected package git.
# Preparing to unpack .../09-git_1%3a2.34.1-1ubuntu1.15_amd64.deb ...
# Unpacking git (1:2.34.1-1ubuntu1.15) ...
# Selecting previously unselected package patch.
# Preparing to unpack .../10-patch_2.7.6-7build2_amd64.deb ...
# Unpacking patch (2.7.6-7build2) ...
# Setting up less (590-1ubuntu0.22.04.3) ...
# Setting up perl-modules-5.34 (5.34.0-3ubuntu1.5) ...
# Setting up patch (2.7.6-7build2) ...
# Setting up git-man (1:2.34.1-1ubuntu1.15) ...
# Setting up netbase (6.3) ...
# Setting up libgdbm6:amd64 (1.23-1) ...
# Setting up libgdbm-compat4:amd64 (1.23-1) ...
# Setting up libperl5.34:amd64 (5.34.0-3ubuntu1.5) ...
# Setting up perl (5.34.0-3ubuntu1.5) ...
# Setting up liberror-perl (0.17029-1) ...
# Setting up git (1:2.34.1-1ubuntu1.15) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# Cloning into 'NLP-Project'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 274 (delta 99), reused 99 (delta 43), pack-reused 92 (from 1)
# Receiving objects: 100% (274/274), 57.80 MiB | 22.69 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# /home/admin/NLP-Project
# data		src
# main.py		train_transformer.py
# notebooks	uv.lock
# pyproject.toml	vlsp
# README.md	VLSP_Qwen_LoRA_Medical_Summarization.ipynb
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -q --upgrade pip
# !pip install -q --upgrade pyparsing torch torchvision torchaudio \
            datasets sentencepiece sacrebleu rouge-score tqdm \
            numpy matplotlib seaborn
# Out:
#   WARNING: The scripts pip, pip3 and pip3.10 are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
#   WARNING: The scripts proton and proton-viewer are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tabulate is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py and numpy-config are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sacrebleu is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace and torchrun are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf and tiny-agents are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import sys
sys.path.insert(0, "/home/admin/.local/lib/python3.10/site-packages")

# %%
from train_transformer import main
config = {
    'src': 'en',
    'trg': 'vi',
    'use_swig': True,
    'use_rope': True,
    'vocab_size_en': 18000,
    'vocab_size_vi': 10500,
    'vocab_model_type': 'unigram',
    'num_workers': 20,

    'model_dim': 384,
    'ff_hidden_dim': 1536,
    'num_heads': 6,
    'num_enc_layers': 4,
    'num_dec_layers': 4,
    'dropout': 0.2,
    'max_len_en': 150,
    'max_len_vi': 180,

    'batch_size': 64,
    'num_epochs': 50,
    'warmup_steps': 4000,
    'train_en_path': 'data/task1/train.en.txt',
    'train_vi_path': 'data/task1/train.vi.txt',
    'valid_en_path': 'data/task1/valid.en.txt',
    'valid_vi_path': 'data/task1/valid.vi.txt',
    'test_en_path': 'data/task1/test.en.txt',
    'test_vi_path': 'data/task1/test.vi.txt',
}

main(config)
# Out:
# Device: cuda
# CONFIGURATION
# src : en
# trg : vi
# use_rope : True
# use_swig : True
# vocab_size_en : 18000
# vocab_size_vi : 10500
# vocab_model_type : unigram
# num_workers : 20
# model_dim : 384
# num_heads : 6
# num_enc_layers : 4
# num_dec_layers : 4
# ff_hidden_dim : 1536
# dropout : 0.2
# max_len_en : 150
# max_len_vi : 180
# batch_size : 64
# num_epochs : 50
# learning_rate : 5e-05
# weight_decay : 1e-05
# warmup_steps : 4000
# patience : 5
# freq_threshold : 2
# beam_size : 5
# length_penalty : 0.6
# train_en_path : data/task1/train.en.txt
# train_vi_path : data/task1/train.vi.txt
# valid_en_path : data/task1/valid.en.txt
# valid_vi_path : data/task1/valid.vi.txt
# test_en_path : data/task1/test.en.txt
# test_vi_path : data/task1/test.vi.txt
# Map:   0%|          | 0/133317 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1553 [00:00<?, ? examples/s]
#   Train samples: 133,317
#   Val samples:   1,268
#   Test samples:  1,553
# ============================================================
#
# Building vocabulary...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.en
#   input_format:
#   model_prefix: spm_en
#   model_type: UNIGRAM
#   vocab_size: 18000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.en
# trainer_interface.cc(411) LOG(INFO) Loaded all 133168 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13164888
# trainer_interface.cc(562) LOG(INFO) Alphabet size=97
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133168 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6701618
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 83413 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133168
# trainer_interface.cc(611) LOG(INFO) Done! 47854
# unigram_model_trainer.cc(602) LOG(INFO) Using 47854 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=33457 obj=9.47102 num_tokens=99225 num_tokens/piece=2.96575
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=25855 obj=7.58489 num_tokens=100273 num_tokens/piece=3.87828
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=19797 obj=7.51373 num_tokens=104658 num_tokens/piece=5.28656
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=19781 obj=7.49587 num_tokens=104760 num_tokens/piece=5.29599
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_en.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_en.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.vi
#   input_format:
#   model_prefix: spm_vi
#   model_type: UNIGRAM
#   vocab_size: 10500
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.vi
# trainer_interface.cc(411) LOG(INFO) Loaded all 133205 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13571933
# trainer_interface.cc(552) LOG(INFO) Done: 99.9548% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=110
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999548
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133205 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6355933
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 29935 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133205
# trainer_interface.cc(611) LOG(INFO) Done! 22399
# unigram_model_trainer.cc(602) LOG(INFO) Using 22399 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=17291 obj=8.22202 num_tokens=46800 num_tokens/piece=2.70661
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=14212 obj=6.87387 num_tokens=46046 num_tokens/piece=3.23994
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=11542 obj=6.79845 num_tokens=46569 num_tokens/piece=4.03474
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=11500 obj=6.78966 num_tokens=46559 num_tokens/piece=4.04861
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_vi.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_vi.vocab
# Creating dataloaders...
# Creating Transformer model...
# Total parameters: 31535364
# Trainable parameters: 31535364
# Setting up training...
# Epoch 1 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.65it/s, loss=3.5774, lr=4.20e-04]
# Epoch 1 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.10it/s, loss=4.5661]
# Epoch 1 | Train: 5.2099 | Val: 4.0413 | LR: 0.000420
# Checkpoint saved: best_model.pt
# Epoch 2 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.95it/s, loss=3.2371, lr=7.90e-04]
# Epoch 2 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.05it/s, loss=3.9773]
# Epoch 2 | Train: 3.7414 | Val: 3.4182 | LR: 0.000790
# Checkpoint saved: best_model.pt
# Epoch 3 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.60it/s, loss=2.8799, lr=6.45e-04]
# Epoch 3 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.79it/s, loss=3.5505]
# Epoch 3 | Train: 3.2998 | Val: 3.0610 | LR: 0.000645
# Checkpoint saved: best_model.pt
# Epoch 4 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.93it/s, loss=2.9333, lr=5.59e-04]
# Epoch 4 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 33.08it/s, loss=3.3894]
# Epoch 4 | Train: 3.0213 | Val: 2.8975 | LR: 0.000559
# Checkpoint saved: best_model.pt
# Epoch 5 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.01it/s, loss=2.7571, lr=5.00e-04]
# Epoch 5 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.19it/s, loss=3.2545]
# Epoch 5 | Train: 2.8559 | Val: 2.8019 | LR: 0.000500
# Checkpoint saved: best_model.pt
# Epoch 6 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.93it/s, loss=2.6443, lr=4.56e-04]
# Epoch 6 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.77it/s, loss=3.1478]
# Epoch 6 | Train: 2.7392 | Val: 2.7360 | LR: 0.000456
# Checkpoint saved: best_model.pt
# Epoch 7 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.82it/s, loss=2.3380, lr=4.23e-04]
# Epoch 7 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.97it/s, loss=3.0803]
# Epoch 7 | Train: 2.6534 | Val: 2.6892 | LR: 0.000423
# Checkpoint saved: best_model.pt
# Epoch 8 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.13it/s, loss=2.5927, lr=3.95e-04]
# Epoch 8 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.55it/s, loss=3.0398]
# Epoch 8 | Train: 2.5842 | Val: 2.6516 | LR: 0.000395
# Checkpoint saved: best_model.pt
# Epoch 9 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.09it/s, loss=2.0549, lr=3.73e-04]
# Epoch 9 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.06it/s, loss=3.0015]
# Epoch 9 | Train: 2.5270 | Val: 2.6324 | LR: 0.000373
# Checkpoint saved: best_model.pt
# Epoch 10 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.96it/s, loss=2.5045, lr=3.53e-04]
# Epoch 10 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.97it/s, loss=2.9454]
# Epoch 10 | Train: 2.4795 | Val: 2.6058 | LR: 0.000353
# Checkpoint saved: best_model.pt
# Epoch 11 [Train]: 100%|██████████| 2084/2084 [01:13<00:00, 28.18it/s, loss=2.3842, lr=3.37e-04]
# Epoch 11 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.09it/s, loss=2.9701]
# Epoch 11 | Train: 2.4383 | Val: 2.5862 | LR: 0.000337
# Checkpoint saved: best_model.pt
# Epoch 12 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.97it/s, loss=2.1982, lr=3.23e-04]
# Epoch 12 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.04it/s, loss=2.9274]
# Epoch 12 | Train: 2.4024 | Val: 2.5753 | LR: 0.000323
# Checkpoint saved: best_model.pt
# Epoch 13 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.01it/s, loss=2.8661, lr=3.10e-04]
# Epoch 13 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.11it/s, loss=2.9158]
# Epoch 13 | Train: 2.3693 | Val: 2.5684 | LR: 0.000310
# Checkpoint saved: best_model.pt
# Epoch 14 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.14it/s, loss=2.5786, lr=2.99e-04]
# Epoch 14 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.35it/s, loss=2.9173]
# Epoch 14 | Train: 2.3401 | Val: 2.5592 | LR: 0.000299
# Checkpoint saved: best_model.pt
# Epoch 15 [Train]: 100%|██████████| 2084/2084 [01:13<00:00, 28.17it/s, loss=2.0834, lr=2.89e-04]
# Epoch 15 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.14it/s, loss=2.8892]
# Epoch 15 | Train: 2.3130 | Val: 2.5547 | LR: 0.000289
# Checkpoint saved: best_model.pt
# Epoch 16 [Train]: 100%|██████████| 2084/2084 [01:13<00:00, 28.18it/s, loss=2.4903, lr=2.79e-04]
# Epoch 16 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.94it/s, loss=2.8921]
# Epoch 16 | Train: 2.2894 | Val: 2.5416 | LR: 0.000279
# Checkpoint saved: best_model.pt
# Epoch 17 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.11it/s, loss=1.8865, lr=2.71e-04]
# Epoch 17 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.19it/s, loss=2.8651]
# Epoch 17 | Train: 2.2665 | Val: 2.5377 | LR: 0.000271
# Checkpoint saved: best_model.pt
# Epoch 18 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.13it/s, loss=2.6631, lr=2.63e-04]
# Epoch 18 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.73it/s, loss=2.8653]
# Epoch 18 | Train: 2.2458 | Val: 2.5379 | LR: 0.000263
# Epoch 19 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.73it/s, loss=1.9726, lr=2.56e-04]
# Epoch 19 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 33.58it/s, loss=2.8662]
# Epoch 19 | Train: 2.2262 | Val: 2.5350 | LR: 0.000256
# Checkpoint saved: best_model.pt
# Epoch 20 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.75it/s, loss=1.9332, lr=2.50e-04]
# Epoch 20 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 34.76it/s, loss=2.8683]
# Epoch 20 | Train: 2.2081 | Val: 2.5345 | LR: 0.000250
# Checkpoint saved: best_model.pt
# Epoch 21 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.11it/s, loss=1.7214, lr=2.44e-04]
# Epoch 21 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.41it/s, loss=2.8619]
# Epoch 21 | Train: 2.1909 | Val: 2.5280 | LR: 0.000244
# Checkpoint saved: best_model.pt
# Epoch 22 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.04it/s, loss=1.9733, lr=2.38e-04]
# Epoch 22 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.71it/s, loss=2.8655]
# Epoch 22 | Train: 2.1737 | Val: 2.5287 | LR: 0.000238
# Epoch 23 [Train]: 100%|██████████| 2084/2084 [01:15<00:00, 27.78it/s, loss=2.0638, lr=2.33e-04]
# Epoch 23 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 34.92it/s, loss=2.8384]
# Epoch 23 | Train: 2.1593 | Val: 2.5290 | LR: 0.000233
# Epoch 24 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.82it/s, loss=2.1033, lr=2.28e-04]
# Epoch 24 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 34.66it/s, loss=2.8548]
# Epoch 24 | Train: 2.1446 | Val: 2.5288 | LR: 0.000228
# Epoch 25 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.05it/s, loss=1.8319, lr=2.24e-04]
# Epoch 25 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.06it/s, loss=2.8585]
# Epoch 25 | Train: 2.1309 | Val: 2.5260 | LR: 0.000224
# Checkpoint saved: best_model.pt
# Epoch 26 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.07it/s, loss=2.1297, lr=2.19e-04]
# Epoch 26 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.55it/s, loss=2.8721]
# Epoch 26 | Train: 2.1182 | Val: 2.5231 | LR: 0.000219
# Checkpoint saved: best_model.pt
# Epoch 27 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.12it/s, loss=1.4073, lr=2.15e-04]
# Epoch 27 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.97it/s, loss=2.8540]
# Epoch 27 | Train: 2.1065 | Val: 2.5221 | LR: 0.000215
# Checkpoint saved: best_model.pt
# Epoch 28 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.10it/s, loss=2.5434, lr=2.11e-04]
# Epoch 28 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.13it/s, loss=2.8706]
# Epoch 28 | Train: 2.0955 | Val: 2.5255 | LR: 0.000211
# Epoch 29 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.13it/s, loss=1.3578, lr=2.08e-04]
# Epoch 29 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.33it/s, loss=2.8734]
# Epoch 29 | Train: 2.0838 | Val: 2.5270 | LR: 0.000208
# Epoch 30 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.02it/s, loss=2.0322, lr=2.04e-04]
# Epoch 30 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.66it/s, loss=2.8660]
# Epoch 30 | Train: 2.0731 | Val: 2.5260 | LR: 0.000204
# Epoch 31 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.82it/s, loss=2.0339, lr=2.01e-04]
# Epoch 31 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.61it/s, loss=2.8680]
# Epoch 31 | Train: 2.0629 | Val: 2.5246 | LR: 0.000201
# Epoch 32 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 27.96it/s, loss=1.9696, lr=1.98e-04]
# Epoch 32 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.58it/s, loss=2.8641]
# Epoch 32 | Train: 2.0534 | Val: 2.5205 | LR: 0.000198
# Checkpoint saved: best_model.pt
# Epoch 33 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.12it/s, loss=1.9413, lr=1.95e-04]
# Epoch 33 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.56it/s, loss=2.8396]
# Epoch 33 | Train: 2.0438 | Val: 2.5255 | LR: 0.000195
# Epoch 34 [Train]: 100%|██████████| 2084/2084 [01:13<00:00, 28.16it/s, loss=2.1553, lr=1.92e-04]
# Epoch 34 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.92it/s, loss=2.8612]
# Epoch 34 | Train: 2.0344 | Val: 2.5306 | LR: 0.000192
# Epoch 35 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.13it/s, loss=2.2054, lr=1.89e-04]
# Epoch 35 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.58it/s, loss=2.8445]
# Epoch 35 | Train: 2.0258 | Val: 2.5231 | LR: 0.000189
# Epoch 36 [Train]: 100%|██████████| 2084/2084 [01:13<00:00, 28.22it/s, loss=2.0219, lr=1.86e-04]
# Epoch 36 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.43it/s, loss=2.8455]
# Epoch 36 | Train: 2.0171 | Val: 2.5304 | LR: 0.000186
# Epoch 37 [Train]: 100%|██████████| 2084/2084 [01:14<00:00, 28.00it/s, loss=1.7896, lr=1.84e-04]
# Epoch 37 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.26it/s, loss=2.8415]
# Epoch 37 | Train: 2.0090 | Val: 2.5319 | LR: 0.000184
# Early stopping at epoch 37
# Training history saved at history.json
# Training completed | Best Val Loss: 2.5205
# 100%|██████████| 1553/1553 [02:17<00:00, 11.27it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 26.06
# 100%|██████████| 1553/1553 [11:45<00:00,  2.20it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 27.22
# Comparison of decoding strategies:
# Greedy BLEU: 26.06
# Beam BLEU:   27.22
# Improvement: 1.17
# ✅ Saved: figures/training_curves.png
# Saved BLEU comparison figure at figures/bleu_comparison.png
# Saved loss histogram at figures/loss_histogram.png
# Saved summary table at figures/summary_table.png
