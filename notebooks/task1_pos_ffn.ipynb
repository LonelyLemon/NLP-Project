# %%
# !sudo apt-get update -qq
# !sudo apt-get install -y -qq git
# !git clone -b full_tf_simple https://github.com/LonelyLemon/NLP-Project.git
# %cd NLP-Project
# !ls
# Out:
# fatal: destination path 'NLP-Project' already exists and is not an empty directory.
# /home/admin/NLP-Project
# best_model.pt			   spm_en.vocab
# data				   spm_vi.model
# main.py				   spm_vi.vocab
# notebooks			   src
# posttraining_schedule_sampling.py  train_transformer.py
# __pycache__			   uv.lock
# pyproject.toml			   vlsp
# README.md			   VLSP_Qwen_LoRA_Medical_Summarization.ipynb
# spm_en.model
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -q --upgrade pip
# !pip install -q --upgrade pyparsing torch torchvision torchaudio \
            datasets sentencepiece sacrebleu rouge-score tqdm \
            numpy matplotlib seaborn

# %%
import sys
sys.path.insert(0, "/home/admin/.local/lib/python3.10/site-packages")

# %%
from train_transformer import main
config = {
    'src': 'en',
    'trg': 'vi',
    'use_swig': False,
    'use_rope': False,
    'vocab_size_en': 18000,
    'vocab_size_vi': 10500,
    'vocab_model_type': 'unigram',
    'num_workers': 20,

    'model_dim': 384,
    'ff_hidden_dim': 1536,
    'num_heads': 6,
    'num_enc_layers': 4,
    'num_dec_layers': 4,
    'dropout': 0.2,
    'max_len_en': 150,
    'max_len_vi': 180,

    'batch_size': 64,
    'num_epochs': 50,
    'warmup_steps': 4000,
    'train_en_path': 'data/task1/train.en.txt',
    'train_vi_path': 'data/task1/train.vi.txt',
    'valid_en_path': 'data/task1/valid.en.txt',
    'valid_vi_path': 'data/task1/valid.vi.txt',
    'test_en_path': 'data/task1/test.en.txt',
    'test_vi_path': 'data/task1/test.vi.txt',
}

main(config)
# Out:
# Device: cuda
# CONFIGURATION
# src : en
# trg : vi
# use_rope : False
# use_swig : False
# vocab_size_en : 18000
# vocab_size_vi : 10500
# vocab_model_type : unigram
# num_workers : 20
# model_dim : 384
# num_heads : 6
# num_enc_layers : 4
# num_dec_layers : 4
# ff_hidden_dim : 1536
# dropout : 0.2
# max_len_en : 150
# max_len_vi : 180
# batch_size : 64
# num_epochs : 50
# learning_rate : 5e-05
# weight_decay : 1e-05
# warmup_steps : 4000
# patience : 5
# freq_threshold : 2
# beam_size : 5
# length_penalty : 0.6
# train_en_path : data/task1/train.en.txt
# train_vi_path : data/task1/train.vi.txt
# valid_en_path : data/task1/valid.en.txt
# valid_vi_path : data/task1/valid.vi.txt
# test_en_path : data/task1/test.en.txt
# test_vi_path : data/task1/test.vi.txt
# Map:   0%|          | 0/133317 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1268 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1553 [00:00<?, ? examples/s]
#   Train samples: 133,317
#   Val samples:   1,268
#   Test samples:  1,553
# ============================================================
#
# Building vocabulary...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.en
#   input_format:
#   model_prefix: spm_en
#   model_type: UNIGRAM
#   vocab_size: 18000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.en
# trainer_interface.cc(411) LOG(INFO) Loaded all 133168 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13164888
# trainer_interface.cc(562) LOG(INFO) Alphabet size=97
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133168 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6701618
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 83413 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133168
# trainer_interface.cc(611) LOG(INFO) Done! 47854
# unigram_model_trainer.cc(602) LOG(INFO) Using 47854 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=33457 obj=9.47102 num_tokens=99225 num_tokens/piece=2.96575
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=25855 obj=7.58489 num_tokens=100273 num_tokens/piece=3.87828
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=19797 obj=7.51373 num_tokens=104658 num_tokens/piece=5.28656
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=19781 obj=7.49587 num_tokens=104760 num_tokens/piece=5.29599
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_en.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_en.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: temp_train.vi
#   input_format:
#   model_prefix: spm_vi
#   model_type: UNIGRAM
#   vocab_size: 10500
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: temp_train.vi
# trainer_interface.cc(411) LOG(INFO) Loaded all 133205 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=13571933
# trainer_interface.cc(552) LOG(INFO) Done: 99.9548% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=110
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999548
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 133205 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6355933
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 29935 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 133205
# trainer_interface.cc(611) LOG(INFO) Done! 22399
# unigram_model_trainer.cc(602) LOG(INFO) Using 22399 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=17291 obj=8.22202 num_tokens=46800 num_tokens/piece=2.70661
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=14212 obj=6.87387 num_tokens=46046 num_tokens/piece=3.23994
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=11542 obj=6.79845 num_tokens=46569 num_tokens/piece=4.03474
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=11500 obj=6.78966 num_tokens=46559 num_tokens/piece=4.04861
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_vi.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_vi.vocab
# Creating dataloaders...
# Creating Transformer model...
# Total parameters: 31550724
# Trainable parameters: 31550724
# Setting up training...
# Epoch 1 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.77it/s, loss=5.5212, lr=4.20e-04]
# Epoch 1 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.79it/s, loss=5.9613]
# Epoch 1 | Train: 18.2125 | Val: 5.5162 | LR: 0.000420
# Checkpoint saved: best_model.pt
# Epoch 2 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.94it/s, loss=4.1659, lr=7.90e-04]
# Epoch 2 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 39.89it/s, loss=5.1547]
# Epoch 2 | Train: 5.1189 | Val: 4.7564 | LR: 0.000790
# Checkpoint saved: best_model.pt
# Epoch 3 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.81it/s, loss=3.8933, lr=6.45e-04]
# Epoch 3 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.26it/s, loss=4.7143]
# Epoch 3 | Train: 4.5893 | Val: 4.1979 | LR: 0.000645
# Checkpoint saved: best_model.pt
# Epoch 4 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.63it/s, loss=4.2954, lr=5.59e-04]
# Epoch 4 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.76it/s, loss=4.3830]
# Epoch 4 | Train: 4.2691 | Val: 3.9005 | LR: 0.000559
# Checkpoint saved: best_model.pt
# Epoch 5 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.78it/s, loss=3.9927, lr=5.00e-04]
# Epoch 5 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.58it/s, loss=4.2060]
# Epoch 5 | Train: 4.0588 | Val: 3.6980 | LR: 0.000500
# Checkpoint saved: best_model.pt
# Epoch 6 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.92it/s, loss=4.6623, lr=4.56e-04]
# Epoch 6 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.74it/s, loss=4.0355]
# Epoch 6 | Train: 3.9026 | Val: 3.5398 | LR: 0.000456
# Checkpoint saved: best_model.pt
# Epoch 7 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.89it/s, loss=3.8177, lr=4.23e-04]
# Epoch 7 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.85it/s, loss=3.9024]
# Epoch 7 | Train: 3.7805 | Val: 3.4421 | LR: 0.000423
# Checkpoint saved: best_model.pt
# Epoch 8 [Train]:  89%|████████▉ | 1855/2084 [01:02<00:07, 29.02it/s, loss=3.6535, lr=3.98e-04]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Epoch 11 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.85it/s, loss=3.2266, lr=3.37e-04]
# Epoch 11 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.70it/s, loss=3.6518]
# Epoch 11 | Train: 3.4823 | Val: 3.1959 | LR: 0.000337
# Checkpoint saved: best_model.pt
# Epoch 12 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.75it/s, loss=2.9990, lr=3.23e-04]
# Epoch 12 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.92it/s, loss=3.6074]
# Epoch 12 | Train: 3.4323 | Val: 3.1418 | LR: 0.000323
# Checkpoint saved: best_model.pt
# Epoch 13 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.90it/s, loss=3.0341, lr=3.10e-04]
# Epoch 13 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.64it/s, loss=3.5750]
# Epoch 13 | Train: 3.3894 | Val: 3.1201 | LR: 0.000310
# Checkpoint saved: best_model.pt
# Epoch 14 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.06it/s, loss=3.4256, lr=2.99e-04]
# Epoch 14 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.67it/s, loss=3.5655]
# Epoch 14 | Train: 3.3504 | Val: 3.0831 | LR: 0.000299
# Checkpoint saved: best_model.pt
# Epoch 15 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.88it/s, loss=3.9985, lr=2.89e-04]
# Epoch 15 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.73it/s, loss=3.5335]
# Epoch 15 | Train: 3.3163 | Val: 3.0486 | LR: 0.000289
# Checkpoint saved: best_model.pt
# Epoch 16 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.81it/s, loss=2.7643, lr=2.79e-04]
# Epoch 16 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.23it/s, loss=3.4864]
# Epoch 16 | Train: 3.2826 | Val: 3.0232 | LR: 0.000279
# Checkpoint saved: best_model.pt
# Epoch 17 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.03it/s, loss=3.3301, lr=2.71e-04]
# Epoch 17 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 45.32it/s, loss=3.4514]
# Epoch 17 | Train: 3.2547 | Val: 3.0020 | LR: 0.000271
# Checkpoint saved: best_model.pt
# Epoch 18 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.00it/s, loss=3.8613, lr=2.63e-04]
# Epoch 18 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 36.10it/s, loss=3.4193]
# Epoch 18 | Train: 3.2267 | Val: 2.9852 | LR: 0.000263
# Checkpoint saved: best_model.pt
# Epoch 19 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.90it/s, loss=3.5129, lr=2.56e-04]
# Epoch 19 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.43it/s, loss=3.4223]
# Epoch 19 | Train: 3.2022 | Val: 2.9803 | LR: 0.000256
# Checkpoint saved: best_model.pt
# Epoch 20 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.92it/s, loss=3.3386, lr=2.50e-04]
# Epoch 20 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.15it/s, loss=3.3662]
# Epoch 20 | Train: 3.1795 | Val: 2.9527 | LR: 0.000250
# Checkpoint saved: best_model.pt
# Epoch 21 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.05it/s, loss=2.9671, lr=2.44e-04]
# Epoch 21 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.23it/s, loss=3.3761]
# Epoch 21 | Train: 3.1563 | Val: 2.9455 | LR: 0.000244
# Checkpoint saved: best_model.pt
# Epoch 22 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.96it/s, loss=2.4709, lr=2.38e-04]
# Epoch 22 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.21it/s, loss=3.3234]
# Epoch 22 | Train: 3.1364 | Val: 2.9186 | LR: 0.000238
# Checkpoint saved: best_model.pt
# Epoch 23 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.96it/s, loss=3.4707, lr=2.33e-04]
# Epoch 23 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.47it/s, loss=3.3521]
# Epoch 23 | Train: 3.1184 | Val: 2.9178 | LR: 0.000233
# Checkpoint saved: best_model.pt
# Epoch 24 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.91it/s, loss=2.8228, lr=2.28e-04]
# Epoch 24 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.38it/s, loss=3.3479]
# Epoch 24 | Train: 3.0993 | Val: 2.8995 | LR: 0.000228
# Checkpoint saved: best_model.pt
# Epoch 25 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.03it/s, loss=3.5255, lr=2.24e-04]
# Epoch 25 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 40.24it/s, loss=3.3126]
# Epoch 25 | Train: 3.0840 | Val: 2.8889 | LR: 0.000224
# Checkpoint saved: best_model.pt
# Epoch 26 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.70it/s, loss=3.2238, lr=2.19e-04]
# Epoch 26 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.40it/s, loss=3.2775]
# Epoch 26 | Train: 3.0671 | Val: 2.8732 | LR: 0.000219
# Checkpoint saved: best_model.pt
# Epoch 27 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.79it/s, loss=3.2365, lr=2.15e-04]
# Epoch 27 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 35.27it/s, loss=3.2990]
# Epoch 27 | Train: 3.0528 | Val: 2.8606 | LR: 0.000215
# Checkpoint saved: best_model.pt
# Epoch 28 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.80it/s, loss=3.0308, lr=2.11e-04]
# Epoch 28 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.42it/s, loss=3.2798]
# Epoch 28 | Train: 3.0380 | Val: 2.8624 | LR: 0.000211
# Epoch 29 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.03it/s, loss=3.7895, lr=2.08e-04]
# Epoch 29 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.05it/s, loss=3.2656]
# Epoch 29 | Train: 3.0243 | Val: 2.8467 | LR: 0.000208
# Checkpoint saved: best_model.pt
# Epoch 30 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.92it/s, loss=3.3001, lr=2.04e-04]
# Epoch 30 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.47it/s, loss=3.2673]
# Epoch 30 | Train: 3.0113 | Val: 2.8473 | LR: 0.000204
# Epoch 31 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.99it/s, loss=2.8598, lr=2.01e-04]
# Epoch 31 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.99it/s, loss=3.2259]
# Epoch 31 | Train: 2.9980 | Val: 2.8353 | LR: 0.000201
# Checkpoint saved: best_model.pt
# Epoch 32 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 30.01it/s, loss=2.5924, lr=1.98e-04]
# Epoch 32 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 41.20it/s, loss=3.2548]
# Epoch 32 | Train: 2.9856 | Val: 2.8291 | LR: 0.000198
# Checkpoint saved: best_model.pt
# Epoch 33 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.79it/s, loss=2.9705, lr=1.95e-04]
# Epoch 33 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 37.69it/s, loss=3.2458]
# Epoch 33 | Train: 2.9748 | Val: 2.8195 | LR: 0.000195
# Checkpoint saved: best_model.pt
# Epoch 34 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.79it/s, loss=3.0289, lr=1.92e-04]
# Epoch 34 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 41.18it/s, loss=3.2289]
# Epoch 34 | Train: 2.9631 | Val: 2.8155 | LR: 0.000192
# Checkpoint saved: best_model.pt
# Epoch 35 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.78it/s, loss=3.3476, lr=1.89e-04]
# Epoch 35 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 41.44it/s, loss=3.2009]
# Epoch 35 | Train: 2.9523 | Val: 2.8062 | LR: 0.000189
# Checkpoint saved: best_model.pt
# Epoch 36 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.99it/s, loss=2.7287, lr=1.86e-04]
# Epoch 36 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.79it/s, loss=3.1915]
# Epoch 36 | Train: 2.9413 | Val: 2.7888 | LR: 0.000186
# Checkpoint saved: best_model.pt
# Epoch 37 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.68it/s, loss=2.8974, lr=1.84e-04]
# Epoch 37 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.23it/s, loss=3.1851]
# Epoch 37 | Train: 2.9318 | Val: 2.7916 | LR: 0.000184
# Epoch 38 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.74it/s, loss=2.0248, lr=1.81e-04]
# Epoch 38 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 44.44it/s, loss=3.1783]
# Epoch 38 | Train: 2.9221 | Val: 2.7813 | LR: 0.000181
# Checkpoint saved: best_model.pt
# Epoch 39 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.77it/s, loss=3.3232, lr=1.79e-04]
# Epoch 39 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 40.49it/s, loss=3.1696]
# Epoch 39 | Train: 2.9117 | Val: 2.7820 | LR: 0.000179
# Epoch 40 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.68it/s, loss=2.4755, lr=1.77e-04]
# Epoch 40 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.53it/s, loss=3.1582]
# Epoch 40 | Train: 2.9031 | Val: 2.7724 | LR: 0.000177
# Checkpoint saved: best_model.pt
# Epoch 41 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.69it/s, loss=2.9942, lr=1.75e-04]
# Epoch 41 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 40.75it/s, loss=3.1742]
# Epoch 41 | Train: 2.8948 | Val: 2.7707 | LR: 0.000175
# Checkpoint saved: best_model.pt
# Epoch 42 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.90it/s, loss=3.7987, lr=1.72e-04]
# Epoch 42 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.58it/s, loss=3.1494]
# Epoch 42 | Train: 2.8859 | Val: 2.7681 | LR: 0.000172
# Checkpoint saved: best_model.pt
# Epoch 43 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.93it/s, loss=3.1364, lr=1.70e-04]
# Epoch 43 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 41.54it/s, loss=3.1332]
# Epoch 43 | Train: 2.8777 | Val: 2.7540 | LR: 0.000170
# Checkpoint saved: best_model.pt
# Epoch 44 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.89it/s, loss=2.5133, lr=1.69e-04]
# Epoch 44 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 40.76it/s, loss=3.1549]
# Epoch 44 | Train: 2.8692 | Val: 2.7514 | LR: 0.000169
# Checkpoint saved: best_model.pt
# Epoch 45 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.88it/s, loss=3.0219, lr=1.67e-04]
# Epoch 45 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.52it/s, loss=3.1695]
# Epoch 45 | Train: 2.8632 | Val: 2.7544 | LR: 0.000167
# Epoch 46 [Train]: 100%|██████████| 2084/2084 [01:10<00:00, 29.71it/s, loss=2.6946, lr=1.65e-04]
# Epoch 46 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 39.72it/s, loss=3.1604]
# Epoch 46 | Train: 2.8541 | Val: 2.7400 | LR: 0.000165
# Checkpoint saved: best_model.pt
# Epoch 47 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.85it/s, loss=2.6289, lr=1.63e-04]
# Epoch 47 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 41.84it/s, loss=3.1492]
# Epoch 47 | Train: 2.8474 | Val: 2.7477 | LR: 0.000163
# Epoch 48 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.84it/s, loss=2.9074, lr=1.61e-04]
# Epoch 48 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 40.78it/s, loss=3.1329]
# Epoch 48 | Train: 2.8395 | Val: 2.7347 | LR: 0.000161
# Checkpoint saved: best_model.pt
# Epoch 49 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.93it/s, loss=1.9431, lr=1.60e-04]
# Epoch 49 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 43.87it/s, loss=3.1358]
# Epoch 49 | Train: 2.8332 | Val: 2.7362 | LR: 0.000160
# Epoch 50 [Train]: 100%|██████████| 2084/2084 [01:09<00:00, 29.88it/s, loss=2.7240, lr=1.58e-04]
# Epoch 50 [Val]  : 100%|██████████| 20/20 [00:00<00:00, 42.92it/s, loss=3.0887]
# Epoch 50 | Train: 2.8273 | Val: 2.7313 | LR: 0.000158
# Checkpoint saved: best_model.pt
# Training history saved at history.json
# Training completed | Best Val Loss: 2.7313
# 100%|██████████| 1553/1553 [01:28<00:00, 17.63it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 22.40
# 100%|██████████| 1553/1553 [07:42<00:00,  3.35it/s]
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU Score: 23.95
# Comparison of decoding strategies:
# Greedy BLEU: 22.40
# Beam BLEU:   23.95
# Improvement: 1.55
# ✅ Saved: figures/training_curves.png
# Saved BLEU comparison figure at figures/bleu_comparison.png
# Saved loss histogram at figures/loss_histogram.png
# Saved summary table at figures/summary_table.png
